# %%
import numpy as np
import pandas as pd
import streamlit as st
data = pd.read_excel('Design_data.xlsx')
data['Grade and class and weight'] = data.agg('{0[Grade and class]}, {0[Nominal weight (in lbf)]} lbf/ft^3'.format, axis=1)
f = data.set_index("Grade and class and weight")

# %%
""""Drillstring Design App by using of Python"""
st.title("Drillstring Design App") 
# add a checkbox to sidebar
check_box = st.sidebar.checkbox(label = 'Display the Dataset')

st.markdown(
    """
    <style>
    .reportview-container {
        background: url("url_goes_here")
    }
   .sidebar .sidebar-content {
        background: url("url_goes_here")
    }
    </style>
    """,
    unsafe_allow_html=True
)

if check_box:
    """"API Drillpipes"""
    st.write(f)
    
st.sidebar.title("Require Data")




Dia = st.sidebar.radio(label = "Select Drillpipe Diameter", options = [2.375, 2.875, 3.5, 4, 4.5, 5 ,5.5, 6.625])

df = f.loc[f["Dia(in inch)"] == Dia]




# multiselect
if Dia == 2.375:
    numeric_cols = ['D -55(Class -1), 4.85 lbf/ft^3', 'D -55(Class -1), 6.65 lbf/ft^3',
       'E -75(Class -1), 4.85 lbf/ft^3', 'E -75(Class -1), 6.65 lbf/ft^3',
       'C -75(Class -1), 4.85 lbf/ft^3', 'C -75(Class -1), 6.65 lbf/ft^3',
       'C -95(Class -1), 4.85 lbf/ft^3', 'C -95(Class -1), 6.65 lbf/ft^3',
       'X -95(Class -1), 4.85 lbf/ft^3', 'X -95(Class -1), 6.65 lbf/ft^3',
       'G -105(Class -1), 4.85 lbf/ft^3', 'G -105(Class -1), 6.65 lbf/ft^3',
       'S -135(Class -1), 4.85 lbf/ft^3', 'S -135(Class -1), 6.65 lbf/ft^3',
       'D -55(Class - P), 4.85 lbf/ft^3', 'D -55(Class - P), 6.65 lbf/ft^3',
       'C -75(Class - P), 4.85 lbf/ft^3', 'C -75(Class - P), 6.65 lbf/ft^3',
       'E -75(Class - P), 4.85 lbf/ft^3', 'E -75(Class - P), 6.65 lbf/ft^3',
       'C -95(Class -P), 4.85 lbf/ft^3', 'C -95(Class -P), 6.65 lbf/ft^3',
       'X -95(Class -P), 4.85 lbf/ft^3', 'X -95(Class -P), 6.65 lbf/ft^3',
       'G -105(Class -P), 4.85 lbf/ft^3', 'G -105(Class -P), 6.65 lbf/ft^3',
       'S -135(Class -P), 4.85 lbf/ft^3', 'S -135(Class -P), 6.65 lbf/ft^3',
       'D -55(Class -2), 4.85 lbf/ft^3', 'D -55(Class -2), 6.65 lbf/ft^3',
       'C -75(Class -2), 4.85 lbf/ft^3', 'C -75(Class -2), 6.65 lbf/ft^3',
       'E -75(Class -2), 4.85 lbf/ft^3', 'E -75(Class -2), 6.65 lbf/ft^3',
       'C -95(Class -2), 4.85 lbf/ft^3', 'C -95(Class -2), 6.65 lbf/ft^3',
       'X -95(Class -2), 4.85 lbf/ft^3', 'X -95(Class -2), 6.65 lbf/ft^3',
       'G -105(Class -2), 4.85 lbf/ft^3', 'G -105(Class -2), 6.65 lbf/ft^3',
       'S -135(Class -2), 4.85 lbf/ft^3', 'S -135(Class -2), 6.65 lbf/ft^3',
       'D -55(Class -3), 4.85 lbf/ft^3', 'D -55(Class -3), 6.65 lbf/ft^3',
       'C -75(Class -3), 4.85 lbf/ft^3', 'C -75(Class -3), 6.65 lbf/ft^3',
       'E -75(Class -3), 4.85 lbf/ft^3', 'E -75(Class -3), 6.65 lbf/ft^3',
       'C -95(Class -3), 4.85 lbf/ft^3', 'C -95(Class -3), 6.65 lbf/ft^3',
       'X -95(Class -3), 4.85 lbf/ft^3', 'X -95(Class -3), 6.65 lbf/ft^3',
       'G -105(Class -3), 4.85 lbf/ft^3', 'G -105(Class -3), 6.65 lbf/ft^3',
       'S -135(Class -3), 4.85 lbf/ft^3', 'S -135(Class -3), 6.65 lbf/ft^3']
elif Dia == 2.875:
    numeric_cols = ['D -55(Class -1), 6.85 lbf/ft^3', 'D -55(Class -1), 10.4 lbf/ft^3',
       'E -75(Class -1), 6.85 lbf/ft^3', 'E -75(Class -1), 10.4 lbf/ft^3',
       'C -75(Class -1), 6.85 lbf/ft^3', 'C -75(Class -1), 10.4 lbf/ft^3',
       'C -95(Class -1), 6.85 lbf/ft^3', 'C -95(Class -1), 10.4 lbf/ft^3',
       'X -95(Class -1), 6.85 lbf/ft^3', 'X -95(Class -1), 10.4 lbf/ft^3',
       'G -105(Class -1), 6.85 lbf/ft^3', 'G -105(Class -1), 10.4 lbf/ft^3',
       'S -135(Class -1), 6.85 lbf/ft^3', 'S -135(Class -1), 10.4 lbf/ft^3',
       'D -55(Class - P), 6.85 lbf/ft^3', 'D -55(Class - P), 10.4 lbf/ft^3',
       'C -75(Class - P), 6.85 lbf/ft^3', 'C -75(Class - P), 10.4 lbf/ft^3',
       'E -75(Class - P), 6.85 lbf/ft^3', 'E -75(Class - P), 10.4 lbf/ft^3',
       'C -95(Class -P), 6.85 lbf/ft^3', 'C -95(Class -P), 10.4 lbf/ft^3',
       'X -95(Class -P), 6.85 lbf/ft^3', 'X -95(Class -P), 10.4 lbf/ft^3',
       'G -105(Class -P), 6.85 lbf/ft^3', 'G -105(Class -P), 10.4 lbf/ft^3',
       'S -135(Class -P), 6.85 lbf/ft^3', 'S -135(Class -P), 10.4 lbf/ft^3',
       'D -55(Class -2), 6.85 lbf/ft^3', 'D -55(Class -2), 10.4 lbf/ft^3',
       'C -75(Class -2), 6.85 lbf/ft^3', 'C -75(Class -2), 10.4 lbf/ft^3',
       'E -75(Class -2), 6.85 lbf/ft^3', 'E -75(Class -2), 10.4 lbf/ft^3',
       'C -95(Class -2), 6.85 lbf/ft^3', 'C -95(Class -2), 10.4 lbf/ft^3',
       'X -95(Class -2), 6.85 lbf/ft^3', 'X -95(Class -2), 10.4 lbf/ft^3',
       'G -105(Class -2), 6.85 lbf/ft^3', 'G -105(Class -2), 10.4 lbf/ft^3',
       'S -135(Class -2), 6.85 lbf/ft^3', 'S -135(Class -2), 10.4 lbf/ft^3',
       'D -55(Class -3), 6.85 lbf/ft^3', 'D -55(Class -3), 10.4 lbf/ft^3',
       'C -75(Class -3), 6.85 lbf/ft^3', 'C -75(Class -3), 10.4 lbf/ft^3',
       'E -75(Class -3), 6.85 lbf/ft^3', 'E -75(Class -3), 10.4 lbf/ft^3',
       'C -95(Class -3), 6.85 lbf/ft^3', 'C -95(Class -3), 10.4 lbf/ft^3',
       'X -95(Class -3), 6.85 lbf/ft^3', 'X -95(Class -3), 10.4 lbf/ft^3',
       'G -105(Class -3), 6.85 lbf/ft^3', 'G -105(Class -3), 10.4 lbf/ft^3',
       'S -135(Class -3), 6.85 lbf/ft^3', 'S -135(Class -3), 10.4 lbf/ft^3']

elif Dia == 3.5:
    numeric_cols = ['D -55(Class -1), 9.5 lbf/ft^3', 'D -55(Class -1), 13.3 lbf/ft^3',
       'D -55(Class -1), 15.5 lbf/ft^3', 'E -75(Class -1), 9.5 lbf/ft^3',
       'E -75(Class -1), 13.3 lbf/ft^3', 'E -75(Class -1), 15.5 lbf/ft^3',
       'C -75(Class -1), 9.5 lbf/ft^3', 'C -75(Class -1), 13.3 lbf/ft^3',
       'C -75(Class -1), 15.5 lbf/ft^3', 'C -95(Class -1), 9.5 lbf/ft^3',
       'C -95(Class -1), 13.3 lbf/ft^3', 'C -95(Class -1), 15.5 lbf/ft^3',
       'X -95(Class -1), 9.5 lbf/ft^3', 'X -95(Class -1), 13.3 lbf/ft^3',
       'X -95(Class -1), 15.5 lbf/ft^3', 'G -105(Class -1), 9.5 lbf/ft^3',
       'G -105(Class -1), 13.3 lbf/ft^3', 'G -105(Class -1), 15.5 lbf/ft^3',
       'S -135(Class -1), 9.5 lbf/ft^3', 'S -135(Class -1), 13.3 lbf/ft^3',
       'S -135(Class -1), 15.5 lbf/ft^3', 'D -55(Class - P), 9.5 lbf/ft^3',
       'D -55(Class - P), 13.3 lbf/ft^3', 'D -55(Class - P), 15.5 lbf/ft^3',
       'C -75(Class - P), 9.5 lbf/ft^3', 'C -75(Class - P), 13.3 lbf/ft^3',
       'C -75(Class - P), 15.5 lbf/ft^3', 'E -75(Class - P), 9.5 lbf/ft^3',
       'E -75(Class - P), 13.3 lbf/ft^3', 'E -75(Class - P), 15.5 lbf/ft^3',
       'C -95(Class -P), 9.5 lbf/ft^3', 'C -95(Class -P), 13.3 lbf/ft^3',
       'C -95(Class -P), 15.5 lbf/ft^3', 'X -95(Class -P), 9.5 lbf/ft^3',
       'X -95(Class -P), 13.3 lbf/ft^3', 'X -95(Class -P), 15.5 lbf/ft^3',
       'G -105(Class -P), 9.5 lbf/ft^3', 'G -105(Class -P), 13.3 lbf/ft^3',
       'G -105(Class -P), 15.5 lbf/ft^3', 'S -135(Class -P), 9.5 lbf/ft^3',
       'S -135(Class -P), 13.3 lbf/ft^3', 'S -135(Class -P), 15.5 lbf/ft^3',
       'D -55(Class -2), 9.5 lbf/ft^3', 'D -55(Class -2), 13.3 lbf/ft^3',
       'D -55(Class -2), 15.5 lbf/ft^3', 'C -75(Class -2), 9.5 lbf/ft^3',
       'C -75(Class -2), 13.3 lbf/ft^3', 'C -75(Class -2), 15.5 lbf/ft^3',
       'E -75(Class -2), 9.5 lbf/ft^3', 'E -75(Class -2), 13.3 lbf/ft^3',
       'E -75(Class -2), 15.5 lbf/ft^3', 'C -95(Class -2), 9.5 lbf/ft^3',
       'C -95(Class -2), 13.3 lbf/ft^3', 'C -95(Class -2), 15.5 lbf/ft^3',
       'X -95(Class -2), 9.5 lbf/ft^3', 'X -95(Class -2), 13.3 lbf/ft^3',
       'X -95(Class -2), 15.5 lbf/ft^3', 'G -105(Class -2), 9.5 lbf/ft^3',
       'G -105(Class -2), 13.3 lbf/ft^3', 'G -105(Class -2), 15.5 lbf/ft^3',
       'S -135(Class -2), 9.5 lbf/ft^3', 'S -135(Class -2), 13.3 lbf/ft^3',
       'S -135(Class -2), 15.5 lbf/ft^3', 'D -55(Class -3), 9.5 lbf/ft^3',
       'D -55(Class -3), 13.3 lbf/ft^3', 'D -55(Class -3), 15.5 lbf/ft^3',
       'C -75(Class -3), 9.5 lbf/ft^3', 'C -75(Class -3), 13.3 lbf/ft^3',
       'C -75(Class -3), 15.5 lbf/ft^3', 'E -75(Class -3), 9.5 lbf/ft^3',
       'E -75(Class -3), 13.3 lbf/ft^3', 'E -75(Class -3), 15.5 lbf/ft^3',
       'C -95(Class -3), 9.5 lbf/ft^3', 'C -95(Class -3), 13.3 lbf/ft^3',
       'C -95(Class -3), 15.5 lbf/ft^3', 'X -95(Class -3), 9.5 lbf/ft^3',
       'X -95(Class -3), 13.3 lbf/ft^3', 'X -95(Class -3), 15.5 lbf/ft^3',
       'G -105(Class -3), 9.5 lbf/ft^3', 'G -105(Class -3), 13.3 lbf/ft^3',
       'G -105(Class -3), 15.5 lbf/ft^3', 'S -135(Class -3), 9.5 lbf/ft^3',
       'S -135(Class -3), 13.3 lbf/ft^3', 'S -135(Class -3), 15.5 lbf/ft^3']
elif Dia == 4:
    numeric_cols = ['D -55(Class -1), 11.85 lbf/ft^3', 'D -55(Class -1), 14.0 lbf/ft^3',
       'D -55(Class -1), 15.7 lbf/ft^3', 'E -75(Class -1), 11.85 lbf/ft^3',
       'E -75(Class -1), 14.0 lbf/ft^3', 'E -75(Class -1), 15.7 lbf/ft^3',
       'C -75(Class -1), 11.85 lbf/ft^3', 'C -75(Class -1), 14.0 lbf/ft^3',
       'C -75(Class -1), 15.7 lbf/ft^3', 'C -95(Class -1), 11.85 lbf/ft^3',
       'C -95(Class -1), 14.0 lbf/ft^3', 'C -95(Class -1), 15.7 lbf/ft^3',
       'X -95(Class -1), 11.85 lbf/ft^3', 'X -95(Class -1), 14.0 lbf/ft^3',
       'X -95(Class -1), 15.7 lbf/ft^3', 'G -105(Class -1), 11.85 lbf/ft^3',
       'G -105(Class -1), 14.0 lbf/ft^3', 'G -105(Class -1), 15.7 lbf/ft^3',
       'S -135(Class -1), 11.85 lbf/ft^3', 'S -135(Class -1), 14.0 lbf/ft^3',
       'S -135(Class -1), 15.7 lbf/ft^3', 'D -55(Class - P), 11.85 lbf/ft^3',
       'D -55(Class - P), 14.0 lbf/ft^3', 'D -55(Class - P), 15.7 lbf/ft^3',
       'C -75(Class - P), 11.85 lbf/ft^3', 'C -75(Class - P), 14.0 lbf/ft^3',
       'C -75(Class - P), 15.7 lbf/ft^3', 'E -75(Class - P), 11.85 lbf/ft^3',
       'E -75(Class - P), 14.0 lbf/ft^3', 'E -75(Class - P), 15.7 lbf/ft^3',
       'C -95(Class -P), 11.85 lbf/ft^3', 'C -95(Class -P), 14.0 lbf/ft^3',
       'C -95(Class -P), 15.7 lbf/ft^3', 'X -95(Class -P), 11.85 lbf/ft^3',
       'X -95(Class -P), 14.0 lbf/ft^3', 'X -95(Class -P), 15.7 lbf/ft^3',
       'G -105(Class -P), 11.85 lbf/ft^3', 'G -105(Class -P), 14.0 lbf/ft^3',
       'G -105(Class -P), 15.7 lbf/ft^3', 'S -135(Class -P), 11.85 lbf/ft^3',
       'S -135(Class -P), 14.0 lbf/ft^3', 'S -135(Class -P), 15.7 lbf/ft^3',
       'D -55(Class -2), 11.85 lbf/ft^3', 'D -55(Class -2), 14.0 lbf/ft^3',
       'D -55(Class -2), 15.7 lbf/ft^3', 'C -75(Class -2), 11.85 lbf/ft^3',
       'C -75(Class -2), 14.0 lbf/ft^3', 'C -75(Class -2), 15.7 lbf/ft^3',
       'E -75(Class -2), 11.85 lbf/ft^3', 'E -75(Class -2), 14.0 lbf/ft^3',
       'E -75(Class -2), 15.7 lbf/ft^3', 'C -95(Class -2), 11.85 lbf/ft^3',
       'C -95(Class -2), 14.0 lbf/ft^3', 'C -95(Class -2), 15.7 lbf/ft^3',
       'X -95(Class -2), 11.85 lbf/ft^3', 'X -95(Class -2), 14.0 lbf/ft^3',
       'X -95(Class -2), 15.7 lbf/ft^3', 'G -105(Class -2), 11.85 lbf/ft^3',
       'G -105(Class -2), 14.0 lbf/ft^3', 'G -105(Class -2), 15.7 lbf/ft^3',
       'S -135(Class -2), 11.85 lbf/ft^3', 'S -135(Class -2), 14.0 lbf/ft^3',
       'S -135(Class -2), 15.7 lbf/ft^3', 'D -55(Class -3), 11.85 lbf/ft^3',
       'D -55(Class -3), 14.0 lbf/ft^3', 'D -55(Class -3), 15.7 lbf/ft^3',
       'C -75(Class -3), 11.85 lbf/ft^3', 'C -75(Class -3), 14.0 lbf/ft^3',
       'C -75(Class -3), 15.7 lbf/ft^3', 'E -75(Class -3), 11.85 lbf/ft^3',
       'E -75(Class -3), 14.0 lbf/ft^3', 'E -75(Class -3), 15.7 lbf/ft^3',
       'C -95(Class -3), 11.85 lbf/ft^3', 'C -95(Class -3), 14.0 lbf/ft^3',
       'C -95(Class -3), 15.7 lbf/ft^3', 'X -95(Class -3), 11.85 lbf/ft^3',
       'X -95(Class -3), 14.0 lbf/ft^3', 'X -95(Class -3), 15.7 lbf/ft^3',
       'G -105(Class -3), 11.85 lbf/ft^3', 'G -105(Class -3), 14.0 lbf/ft^3',
       'G -105(Class -3), 15.7 lbf/ft^3', 'S -135(Class -3), 11.85 lbf/ft^3',
       'S -135(Class -3), 14.0 lbf/ft^3', 'S -135(Class -3), 15.7 lbf/ft^3']

elif Dia == 4.5:
    numeric_cols = ['D -55(Class -1), 13.75 lbf/ft^3', 'D -55(Class -1), 16.6 lbf/ft^3',
       'D -55(Class -1), 20.0 lbf/ft^3', 'E -75(Class -1), 13.75 lbf/ft^3',
       'E -75(Class -1), 16.6 lbf/ft^3', 'E -75(Class -1), 20.0 lbf/ft^3',
       'C -75(Class -1), 13.75 lbf/ft^3', 'C -75(Class -1), 16.6 lbf/ft^3',
       'C -75(Class -1), 20.0 lbf/ft^3', 'C -95(Class -1), 13.75 lbf/ft^3',
       'C -95(Class -1), 16.6 lbf/ft^3', 'C -95(Class -1), 20.0 lbf/ft^3',
       'X -95(Class -1), 13.75 lbf/ft^3', 'X -95(Class -1), 16.6 lbf/ft^3',
       'X -95(Class -1), 20.0 lbf/ft^3', 'G -105(Class -1), 13.75 lbf/ft^3',
       'G -105(Class -1), 16.6 lbf/ft^3', 'G -105(Class -1), 20.0 lbf/ft^3',
       'S -135(Class -1), 13.75 lbf/ft^3', 'S -135(Class -1), 16.6 lbf/ft^3',
       'S -135(Class -1), 20.0 lbf/ft^3', 'D -55(Class - P), 13.75 lbf/ft^3',
       'D -55(Class - P), 16.6 lbf/ft^3', 'D -55(Class - P), 20.0 lbf/ft^3',
       'C -75(Class -P), 13.75 lbf/ft^3', 'C -75(Class -P), 16.6 lbf/ft^3',
       'C -75(Class -P), 20.0 lbf/ft^3', 'E -75(Class - P), 13.75 lbf/ft^3',
       'E -75(Class - P), 16.6 lbf/ft^3', 'E -75(Class - P), 20.0 lbf/ft^3',
       'C -95(Class -P), 13.75 lbf/ft^3', 'C -95(Class -P), 16.6 lbf/ft^3',
       'C -95(Class -P), 20.0 lbf/ft^3', 'X -95(Class -P), 13.75 lbf/ft^3',
       'X -95(Class -P), 16.6 lbf/ft^3', 'X -95(Class -P), 20.0 lbf/ft^3',
       'G -105(Class -P), 13.75 lbf/ft^3', 'G -105(Class -P), 16.6 lbf/ft^3',
       'G -105(Class -P), 20.0 lbf/ft^3', 'S -135(Class -P), 13.75 lbf/ft^3',
       'S -135(Class -P), 16.6 lbf/ft^3', 'S -135(Class -P), 20.0 lbf/ft^3',
       'D -55(Class -2), 13.75 lbf/ft^3', 'D -55(Class -2), 16.6 lbf/ft^3',
       'D -55(Class -2), 20.0 lbf/ft^3', 'C -75(Class -2), 13.75 lbf/ft^3',
       'C -75(Class -2), 16.6 lbf/ft^3', 'C -75(Class -2), 20.0 lbf/ft^3',
       'E -75(Class -2), 13.75 lbf/ft^3', 'E -75(Class -2), 16.6 lbf/ft^3',
       'E -75(Class -2), 20.0 lbf/ft^3', 'C -95(Class -2), 13.75 lbf/ft^3',
       'C -95(Class -2), 16.6 lbf/ft^3', 'C -95(Class -2), 20.0 lbf/ft^3',
       'X -95(Class -2), 13.75 lbf/ft^3', 'X -95(Class -2), 16.6 lbf/ft^3',
       'X -95(Class -2), 20.0 lbf/ft^3', 'G -105(Class -2), 13.75 lbf/ft^3',
       'G -105(Class -2), 16.6 lbf/ft^3', 'G -105(Class -2), 20.0 lbf/ft^3',
       'S -135(Class -2), 13.75 lbf/ft^3', 'S -135(Class -2), 16.6 lbf/ft^3',
       'S -135(Class -2), 20.0 lbf/ft^3', 'D -55(Class -3), 13.75 lbf/ft^3',
       'D -55(Class -3), 16.6 lbf/ft^3', 'D -55(Class -3), 20.0 lbf/ft^3',
       'C -75(Class -3), 13.75 lbf/ft^3', 'C -75(Class -3), 16.6 lbf/ft^3',
       'C -75(Class -3), 20.0 lbf/ft^3', 'E -75(Class -3), 13.75 lbf/ft^3',
       'E -75(Class -3), 16.6 lbf/ft^3', 'E -75(Class -3), 20.0 lbf/ft^3',
       'C -95(Class -3), 13.75 lbf/ft^3', 'C -95(Class -3), 16.6 lbf/ft^3',
       'C -95(Class -3), 20.0 lbf/ft^3', 'X -95(Class -3), 13.75 lbf/ft^3',
       'X -95(Class -3), 16.6 lbf/ft^3', 'X -95(Class -3), 20.0 lbf/ft^3',
       'G -105(Class -3), 13.75 lbf/ft^3', 'G -105(Class -3), 16.6 lbf/ft^3',
       'G -105(Class -3), 20.0 lbf/ft^3', 'S -135(Class -3), 13.75 lbf/ft^3',
       'S -135(Class -3), 16.6 lbf/ft^3', 'S -135(Class -3), 20.0 lbf/ft^3']

elif Dia == 5:
    numeric_cols = ['D -55(Class -1), 16.26 lbf/ft^3', 'D -55(Class -1), 19.5 lbf/ft^3',
       'D -55(Class -1), 25.6 lbf/ft^3', 'E -75(Class -1), 16.25 lbf/ft^3',
       'E -75(Class -1), 19.5 lbf/ft^3', 'E -75(Class -1), 25.6 lbf/ft^3',
       'C -75(Class -1), 16.25 lbf/ft^3', 'C -75(Class -1), 19.5 lbf/ft^3',
       'C -75(Class -1), 25.6 lbf/ft^3', 'C -95(Class -1), 16.25 lbf/ft^3',
       'C -95(Class -1), 19.5 lbf/ft^3', 'C -95(Class -1), 25.6 lbf/ft^3',
       'X -95(Class -1), 16.25 lbf/ft^3', 'X -95(Class -1), 19.5 lbf/ft^3',
       'X -95(Class -1), 25.6 lbf/ft^3', 'G -105(Class -1), 16.25 lbf/ft^3',
       'G -105(Class -1), 19.5 lbf/ft^3', 'G -105(Class -1), 25.6 lbf/ft^3',
       'S -135(Class -1), 16.25 lbf/ft^3', 'S -135(Class -1), 19.5 lbf/ft^3',
       'S -135(Class -1), 25.6 lbf/ft^3', 'D -55(Class - P), 16.25 lbf/ft^3',
       'D -55(Class - P), 19.5 lbf/ft^3', 'D -55(Class - P), 25.6 lbf/ft^3',
       'C -75(Class -P), 16.25 lbf/ft^3', 'C -75(Class -P), 19.5 lbf/ft^3',
       'C -75(Class - P), 25.6 lbf/ft^3', 'E -75(Class - P), 16.25 lbf/ft^3',
       'E -75(Class - P), 19.5 lbf/ft^3', 'E -75(Class - P), 25.6 lbf/ft^3',
       'C -95(Class -P), 16.25 lbf/ft^3', 'C -95(Class -P), 19.5 lbf/ft^3',
       'C -95(Class -P), 25.6 lbf/ft^3', 'X -95(Class -P), 16.25 lbf/ft^3',
       'X -95(Class -P), 19.5 lbf/ft^3', 'X -95(Class -P), 25.6 lbf/ft^3',
       'G -105(Class -P), 16.25 lbf/ft^3', 'G -105(Class -P), 19.5 lbf/ft^3',
       'G -105(Class -P), 25.6 lbf/ft^3', 'S -135(Class -P), 16.25 lbf/ft^3',
       'S -135(Class -P), 19.5 lbf/ft^3', 'S -135(Class -P), 25.6 lbf/ft^3',
       'D -55(Class -2), 16.25 lbf/ft^3', 'D -55(Class -2), 19.5 lbf/ft^3',
       'D -55(Class -2), 25.6 lbf/ft^3', 'C -75(Class -2), 16.25 lbf/ft^3',
       'C -75(Class -2), 19.5 lbf/ft^3', 'C -75(Class -2), 25.6 lbf/ft^3',
       'E -75(Class -2), 16.25 lbf/ft^3', 'E -75(Class -2), 19.5 lbf/ft^3',
       'E -75(Class -2), 25.6 lbf/ft^3', 'C -95(Class -2), 16.25 lbf/ft^3',
       'C -95(Class -2), 19.5 lbf/ft^3', 'C -95(Class -2), 25.6 lbf/ft^3',
       'X -95(Class -2), 16.25 lbf/ft^3', 'X -95(Class -2), 19.5 lbf/ft^3',
       'X -95(Class -2), 25.6 lbf/ft^3', 'G -105(Class -2), 16.25 lbf/ft^3',
       'G -105(Class -2), 19.5 lbf/ft^3', 'G -105(Class -2), 25.6 lbf/ft^3',
       'S -135(Class -2), 16.25 lbf/ft^3', 'S -135(Class -2), 19.5 lbf/ft^3',
       'S -135(Class -2), 25.6 lbf/ft^3', 'D -55(Class -3), 16.25 lbf/ft^3',
       'D -55(Class -3), 19.5 lbf/ft^3', 'D -55(Class -3), 25.6 lbf/ft^3',
       'C -75(Class -3), 19.5 lbf/ft^3', 'C -75(Class -3), 25.6 lbf/ft^3',
       'E -75(Class -3), 19.5 lbf/ft^3', 'E -75(Class -3), 25.6 lbf/ft^3',
       'C -95(Class -3), 16.25 lbf/ft^3', 'C -95(Class -3), 19.5 lbf/ft^3',
       'C -95(Class -3), 25.6 lbf/ft^3', 'X -95(Class -3), 16.25 lbf/ft^3',
       'X -95(Class -3), 19.5 lbf/ft^3', 'X -95(Class -3), 25.6 lbf/ft^3',
       'G -105(Class -3), 16.25 lbf/ft^3', 'G -105(Class -3), 19.5 lbf/ft^3',
       'G -105(Class -3), 25.6 lbf/ft^3', 'S -135(Class -3), 16.25 lbf/ft^3',
       'S -135(Class -3), 19.5 lbf/ft^3', 'S -135(Class -3), 25.6 lbf/ft^3']
elif Dia == 5.5:
    numeric_cols = ['D -55(Class -1), 19.2 lbf/ft^3', 'D -55(Class -1), 21.9 lbf/ft^3',
       'D -55(Class -1), 24.7 lbf/ft^3', 'E -75(Class -1), 19.2 lbf/ft^3',
       'E -75(Class -1), 21.9 lbf/ft^3', 'E -75(Class -1), 24.7 lbf/ft^3',
       'C -75(Class -1), 19.2 lbf/ft^3', 'C -75(Class -1), 21.9 lbf/ft^3',
       'C -75(Class -1), 24.7 lbf/ft^3', 'C -95(Class -1), 19.2 lbf/ft^3',
       'C -95(Class -1), 21.9 lbf/ft^3', 'C -95(Class -1), 24.7 lbf/ft^3',
       'X -95(Class -1), 19.2 lbf/ft^3', 'X -95(Class -1), 21.9 lbf/ft^3',
       'X -95(Class -1), 24.7 lbf/ft^3', 'G -105(Class -1), 19.2 lbf/ft^3',
       'G -105(Class -1), 21.9 lbf/ft^3', 'G -105(Class -1), 24.7 lbf/ft^3',
       'S -135(Class -1), 19.2 lbf/ft^3', 'S -135(Class -1), 21.9 lbf/ft^3',
       'S -135(Class -1), 24.7 lbf/ft^3', 'D -55(Class - P), 19.2 lbf/ft^3',
       'D -55(Class - P), 21.9 lbf/ft^3', 'D -55(Class - P), 24.7 lbf/ft^3',
       'C -75(Class - P), 19.2 lbf/ft^3', 'C -75(Class - P), 21.9 lbf/ft^3',
       'C -75(Class - P), 24.7 lbf/ft^3', 'E -75(Class - P), 19.2 lbf/ft^3',
       'E -75(Class - P), 21.9 lbf/ft^3', 'E -75(Class - P), 24.7 lbf/ft^3',
       'C -95(Class -P), 19.2 lbf/ft^3', 'C -95(Class -P), 21.9 lbf/ft^3',
       'C -95(Class -P), 24.7 lbf/ft^3', 'X -95(Class -P), 19.2 lbf/ft^3',
       'X -95(Class -P), 21.9 lbf/ft^3', 'X -95(Class -P), 24.7 lbf/ft^3',
       'G -105(Class -P), 19.2 lbf/ft^3', 'G -105(Class -P), 21.9 lbf/ft^3',
       'G -105(Class -P), 24.7 lbf/ft^3', 'S -135(Class -P), 19.2 lbf/ft^3',
       'S -135(Class -P), 21.9 lbf/ft^3', 'S -135(Class -P), 24.7 lbf/ft^3',
       'D -55(Class -2), 19.2 lbf/ft^3', 'D -55(Class -2), 21.9 lbf/ft^3',
       'D -55(Class -2), 24.7 lbf/ft^3', 'C -75(Class -2), 19.2 lbf/ft^3',
       'C -75(Class -2), 21.9 lbf/ft^3', 'C -75(Class -2), 24.7 lbf/ft^3',
       'E -75(Class -2), 19.2 lbf/ft^3', 'E -75(Class -2), 21.9 lbf/ft^3',
       'E -75(Class -2), 24.7 lbf/ft^3', 'C -95(Class -2), 19.2 lbf/ft^3',
       'C -95(Class -2), 21.9 lbf/ft^3', 'C -95(Class -2), 24.7 lbf/ft^3',
       'X -95(Class -2), 19.2 lbf/ft^3', 'X -95(Class -2), 21.9 lbf/ft^3',
       'X -95(Class -2), 24.7 lbf/ft^3', 'G -105(Class -2), 19.2 lbf/ft^3',
       'G -105(Class -2), 21.9 lbf/ft^3', 'G -105(Class -2), 24.7 lbf/ft^3',
       'S -135(Class -2), 19.2 lbf/ft^3', 'S -135(Class -2), 21.9 lbf/ft^3',
       'S -135(Class -2), 24.7 lbf/ft^3', 'D -55(Class -3), 19.2 lbf/ft^3',
       'D -55(Class -3), 21.9 lbf/ft^3', 'D -55(Class -3), 24.7 lbf/ft^3',
       'C -75(Class -3), 19.2 lbf/ft^3', 'C -75(Class -3), 21.9 lbf/ft^3',
       'C -75(Class -3), 24.7 lbf/ft^3', 'E -75(Class -3), 19.2 lbf/ft^3',
       'E -75(Class -3), 21.9 lbf/ft^3', 'E -75(Class -3), 24.7 lbf/ft^3',
       'C -95(Class -3), 19.2 lbf/ft^3', 'C -95(Class -3), 21.9 lbf/ft^3',
       'C -95(Class -3), 24.7 lbf/ft^3', 'X -95(Class -3), 19.2 lbf/ft^3',
       'X -95(Class -3), 21.9 lbf/ft^3', 'X -95(Class -3), 24.7 lbf/ft^3',
       'G -105(Class -3), 19.2 lbf/ft^3', 'G -105(Class -3), 21.9 lbf/ft^3',
       'G -105(Class -3), 24.7 lbf/ft^3', 'S -135(Class -3), 19.2 lbf/ft^3',
       'S -135(Class -3), 21.9 lbf/ft^3', 'S -135(Class -3), 24.7 lbf/ft^3']
else:
    numeric_cols = ['D -55(Class -1), 25.2 lbf/ft^3', 'E -75(Class -1), 25.2 lbf/ft^3',
       'C -75(Class -1), 25.2 lbf/ft^3', 'C -95(Class -1), 25.2 lbf/ft^3',
       'X -95(Class -1), 25.2 lbf/ft^3', 'G -105(Class -1), 25.2 lbf/ft^3',
       'S -135(Class -1), 25.2 lbf/ft^3', 'D -55(Class - P), 25.2 lbf/ft^3',
       'C -75(Class - P), 25.2 lbf/ft^3', 'E -75(Class - P), 25.2 lbf/ft^3',
       'C -95(Class -P), 25.2 lbf/ft^3', 'X -95(Class -P), 25.2 lbf/ft^3',
       'G -105(Class -P), 25.2 lbf/ft^3', 'S -135(Class -P), 25.2 lbf/ft^3',
       'D -55(Class -2), 25.2 lbf/ft^3', 'C -75(Class -2), 25.2 lbf/ft^3',
       'E -75(Class -2), 25.2 lbf/ft^3', 'C -95(Class -2), 25.2 lbf/ft^3',
       'X -95(Class -2), 25.2 lbf/ft^3', 'G -105(Class -2), 25.2 lbf/ft^3',
       'S -135(Class -2), 25.2 lbf/ft^3', 'D -55(Class -3), 25.2 lbf/ft^3',
       'C -75(Class -3), 25.2 lbf/ft^3', 'E -75(Class -3), 25.2 lbf/ft^3',
       'C -95(Class -3), 25.2 lbf/ft^3', 'X -95(Class -3), 25.2 lbf/ft^3',
       'G -105(Class -3), 25.2 lbf/ft^3', 'S -135(Class -3), 25.2 lbf/ft^3']
    

    

    
feature_selection = st.sidebar.multiselect(label = "Select Avilable Drillpipe", 
                                           options = numeric_cols)

### print the given pipes
def picker(feature_selection,df):
    df_results = pd.DataFrame(data = np.zeros(df.shape), columns = df.columns)
    df_results = df_results.iloc[:len(feature_selection),:]
    df_results.index = pd.Series(data = feature_selection, name = "pipe")
    for pipe in feature_selection:
        df_results.loc[pipe] = df.loc[pipe]
    
    return df_results
dd = picker(feature_selection,df)
""""Avilable Drillpipes"""
st.write(dd)
  

Mud_weight  = st.sidebar.number_input(label="Mud_weight(in ppg)", step = 0.01)
Well_depth = st.sidebar.number_input(label = "WElldepth(in feet)", step = 0.01)
Mop = st.sidebar.number_input(label = "Mop (in lbf)", step =  0.01)
SFT = st.sidebar.number_input(label = 'Safty factor', step = 0.01)
WOB = st.sidebar.number_input(label = "Weight_on_bit (in lbf)", step =  0.01)
FPG = st.sidebar.number_input(label = 'Fracture Pressure Grident in psi', step = 0.01)
Well_Bore_size = st.sidebar.number_input(label ="Well_bore_size (in inch)", step = 0.01)
Wc = st.sidebar.number_input(label="Weight_of_Drillcollar(lbf/ft)", step = 0.01)
Wp = st.sidebar.number_input(label="Weight_of_Drillpipe(lbf/ft)", step = 0.01)

####Selection
pf = Well_depth * FPG

aa = dd.loc[dd["Brust Perssure (in psi)"] >= pf]
B = float(1- Mud_weight/65.4)
Ldc = float((WOB + Well_depth * Wp * (1 - B))/(Wc - (1 - B) * (Wp - Wc)))
st.write(f'Drill collar size = {Ldc} feet (from {Well_depth - Ldc} feet to {Well_depth} feet) ')
ph = 0.052 * Mud_weight * (Well_depth - Ldc)

pp = aa.loc[dd["Colleapse Pressure (in psi)"] > ph]
bb = pp.sort_values(by = 'Pipe body strength(in lbf)')
st.write(bb)
a = ((bb.iloc[0,7] * 0.9) - Mop)/((bb.iloc[0,2]) * B ) - ((Ldc * Wc) / (bb.iloc[0,2]))
b = ((bb.iloc[0,7] * 0.9))/((bb.iloc[0,2]) *SFT * B ) - ((Ldc * Wc) / (bb.iloc[0,2]))
if (Ldc + a) > Well_depth or (Ldc + b) > Well_depth:
    Lp1 = (Well_depth - Ldc)
else:
    if a < b:
        Lp1 = a
    else: 
        Lp1 = b
st.write(f'Section_1 size is =  {Lp1} feet (from {Well_depth - Lp1 - Ldc} feet to {Well_depth - Ldc} feet use drill pipe {bb.index[0]})')

Depth_left = Well_depth - Ldc - Lp1

a1 = ((bb.iloc[1,7] * 0.9) - Mop)/((bb.iloc[1,2]) * B ) - (((Ldc * Wc) + (Lp1 * (bb.iloc[0,2])))   / (bb.iloc[1,2]))
b2 = ((bb.iloc[1,7] * 0.9))/((bb.iloc[1,2]) *SFT * B ) - (((Ldc * Wc) + (Lp1 * (bb.iloc[0,2]))) / (bb.iloc[1,2]))


if (Lp1 + Ldc) >= Well_depth:
    Lp2 = 0
elif (Lp1 + Ldc) < Well_depth and Well_depth < (Lp1 + Ldc + a1) and Well_depth < (Lp1 + Ldc + b2):
    Lp2 = (Well_depth - Ldc - Lp1)

else:
    if a < b:
        Lp2 = a1
    else: 
        Lp2 = b2

st.write(f'Section_2 size is =  {Lp2} feet (from {Well_depth - Lp2 -Lp1 - Ldc } feet to {Well_depth - Lp1 - Ldc} feet use drill pipe {bb.index[1]} )')       
if (Ldc - Lp1 - Lp2) > Well_depth:
    Lp3 = 0
else:
    Lp3 = Well_depth - Ldc - Lp1 - Lp2
    
st.write(f'Section_3 size is =  {Lp3} feet (from Surface to {Well_depth - Lp2 - Lp1 - Ldc} feet use drill pipe {bb.index[2]})' )
