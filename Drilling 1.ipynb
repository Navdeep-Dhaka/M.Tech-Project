# %%
Dia = float(input("enter diameter of pipe (in inch) : "))
Ym = float(input("enter value of specified minimum yield strength (in psi) : "))
t = float(input("enter nominal wall thickness (in inches) : "))
Ratio = Dia/t
Burst_pressure = 1.75* Ym/Ratio
print(f"Burst pressure for this pipe = {Burst_pressure} psi")
J = 3.1415926/32 * (Dia**4 - ( Dia - 2*t)**4)
Q = 0.096167 * J* Ym/Dia
print(f"Minimum torsional strength for this pipe = {Q} lb-ft")
F = 3.1415926/4 * Ym *(Dia**2 -(Dia - 2*t)**2)
print(f"Pipe body strength for this pipe = {F} lbf")
if Ym == 40000:
    A = 2.95
    B = 0.0465
    C = 754
    D = 2.063
    E = 0.0325
    if Ratio<= 16.40:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi ")
    elif 16.4 <Ratio < 27.01 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 27.01 < Ratio < 42.64:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi ")
elif Ym == 50000:
    A = 2.976
    B = 0.0515
    C = 1056
    D = 2.003
    E = 0.0347
    if Ratio<= 15.24:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi ")
    elif 15.24 <Ratio < 25.63 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 25.63 < Ratio < 38.83:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 55000:
    A = 2.991
    B = 0.0541
    C = 1206
    D = 1.989
    E = 0.036
    if Ratio <= 14.8:
        Pc = 2 * Ym * (Ratio - 1) / Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi ")
    elif 14.8 < Ratio < 24.99:
        Pc = (Ym * ((A / Ratio) - B)) - C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 24.99 < Ratio < 37.2:
        Pc = Ym * (D / Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else:
        Pc = 46.95 * 10 ** 6 / (Ratio * (Ratio - 1) ** 2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi ")
elif Ym == 60000:
    A = 3.005
    B = 0.0566
    C = 1356
    D = 1.983
    E = 0.0373
    if Ratio<= 14.44:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 14.44 <Ratio < 24.42 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 24.42 < Ratio < 35.73:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 70000:
    A = 3.037
    B = 0.0617
    C = 1656
    D = 1.984
    E = 0.0403
    if Ratio<= 13.85:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 13.85 <Ratio < 23.38 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi ")
    elif 23.38 < Ratio < 33.17:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 75000:
    A = 3.054
    B = 0.0642
    C = 1806
    D = 1.99
    E = 0.0418
    if Ratio <= 13.67:
        Pc = 2 * Ym * (Ratio - 1) / Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 13.67 < Ratio < 23.09:
        Pc = (Ym * ((A / Ratio) - B)) - C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 23.09 < Ratio < 32.05:
        Pc = Ym * (D / Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi ")
    else:
        Pc = 46.95 * 10 ** 6 / (Ratio * (Ratio - 1) ** 2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 80000:
    A = 3.071
    B = 0.0667
    C = 1955
    D = 1.998
    E = 0.0434
    if Ratio<= 13.38:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 13.38 <Ratio < 22.47 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi ")
    elif 22.47 < Ratio < 31.02:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 90000:
    A = 3.106
    B = 0.0718
    C = 2254
    D = 2.017
    E = 0.0466
    if Ratio<= 13.01:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 13.01 <Ratio < 21.69 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 21.69 < Ratio < 29.18:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 95000:
    A = 3.124
    B = 0.0743
    C = 2404
    D = 2.029
    E = 0.0482
    if Ratio<= 12.85:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 12.85 <Ratio < 21.33 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 21.33 < Ratio < 28.36:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 100000:
    A = 3.143
    B = 0.0768
    C = 2553
    D = 2.040
    E = 0.0499
    if Ratio<= 12.70:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi ")
    elif 12.70 <Ratio < 21.00 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 21.00 < Ratio < 27.6:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi ")
elif Ym == 105000:
    A = 3.162
    B = 0.0795
    C = 2700
    D = 2052
    E = 0.0515
    if Ratio <= 12.57:
        Pc = 2 * Ym * (Ratio - 1) / Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi ")
    elif 12.57 < Ratio < 20.70:
        Pc = (Ym * ((A / Ratio) - B)) - C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 20.70 < Ratio < 26.89:
        Pc = Ym * (D / Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else:
        Pc = 46.95 * 10 ** 6 / (Ratio * (Ratio - 1) ** 2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 110000:
    A = 3.181
    B = 0.0819
    C = 2852
    D = 2.066
    E = 0.0532
    if Ratio<= 12.44:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 12.44 <Ratio < 20.41 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 20.41 < Ratio < 26.22:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 120000:
    A = 3.219
    B = 0.0870
    C = 3151
    D = 2.092
    E = 0.0565
    if Ratio<= 12.21:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 12.21 <Ratio < 19.88 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi ")
    elif 19.88 < Ratio < 25.01:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 125000:
    A = 3.239
    B = 0.0895
    C = 3301
    D = 2.106
    E = 0.0582
    if Ratio<= 12.11:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 12.11 <Ratio < 19.63 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 19.63 < Ratio < 24.46:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 130000:
    A = 3.258
    B = 0.0920
    C = 3451
    D = 2119
    E = 0.0599
    if Ratio<= 12.02:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 12.02 <Ratio < 19.4 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 19.4 < Ratio < 23.94:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 135000:
    A = 3.278
    B = 0.0946
    C = 3601
    D = 2.133
    E = 0.0615
    if Ratio<= 11.92:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 11.92 <Ratio < 19.18 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 19.18 < Ratio < 23.44:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 140000:
    A = 3.297
    B = 0.0971
    C = 3751
    D = 2.146
    E = 0.0632
    if Ratio<= 11.84:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 11.84 <Ratio < 18.97 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 18.97 < Ratio < 22.98:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 150000:
    A = 3.336
    B = 0.1021
    C = 4053
    D = 2.174
    E = 0.0666
    if Ratio<= 11.67:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi ")
    elif 11.67 <Ratio < 18.57 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 18.57 < Ratio < 22.11:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 155000:
    A = 3.356
    B = 0.1047
    C = 4204
    D = 2.188
    E = 0.0683
    if Ratio<= 11.59:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 11.59 <Ratio < 18.37 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 18.37 < Ratio < 21.7:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 160000:
    A = 3.375
    B = 0.1072
    C = 4356
    D = 2.202
    E = 0.0700
    if Ratio<= 11.52:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 11.52 <Ratio < 18.19 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 18.19 < Ratio < 21.32:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 170000:
    A = 3.412
    B = 0.1123
    C = 4660
    D = 2.231
    E = 0.0734
    if Ratio<= 11.37:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 11.37 <Ratio < 17.82 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 17.82 < Ratio < 20.6:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
elif Ym == 180000:
    A = 3.449
    B = 0.1173
    C = 4966
    D = 2.261
    E = 0.0769
    if Ratio<= 11.23:
        Pc = 2*Ym *(Ratio-1)/Ratio**2
        print(f"This pipe is in Yield stress collapse region and collapse ratting = {Pc} psi")
    elif 11.23 <Ratio < 17.47 :
        Pc = (Ym * ((A/Ratio) - B))- C
        print(f"This pipe is in plastic collapse region and collapse ratting = {Pc} psi")
    elif 17.47 < Ratio < 19.93:
        Pc = Ym * ( D/Ratio - E)
        print(f"This pipe is in transiant collapse region and collapse ratting = {Pc} psi ")
    else :
        Pc = 46.95 * 10**6 / (Ratio * (Ratio -1)**2)
        print(f"This pipe is in elastic collapse region and collapse ratting = {Pc} psi")
# Out:
# enter diameter of pipe (in inch) : 5
# enter value of specified minimum yield strength (in psi) : 95000
# enter nominal wall thickness (in inches) : 0.296
# Burst pressure for this pipe = 9842.0 psi
# Minimum torsional strength for this pipe = 44389.41486171014 lb-ft
# Pipe body strength for this pipe = 415558.8107220477 lbf
# This pipe is in plastic collapse region and collapse ratting = 8106.876 psi
